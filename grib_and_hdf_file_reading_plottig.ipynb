# %% [markdown]
# # code to read and write grib and hdf file using xarray

# %%
import pygrib as pg
import h5py as h5
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap, cm
import xarray as xr
#import cfgrib
plt.rcParams.update({'font.size': 14})
# Out:
# /home/mukesh/anaconda3/lib/python3.9/site-packages/xarray/backends/cfgrib_.py:27: UserWarning: Failed to load cfgrib - most likely there is a problem accessing the ecCodes library. Try `import cfgrib` to get the full error message
#   warnings.warn(

# %%
gfile = 'test.grib2'
h5file ='test.h5'

# %%
#gdataset  = pg.open(gfile)
#gdataset = xr.open_dataset(gfile,engine='cfgrib',backend_kwargs={'indexpath':''} )
hdataset =   h5.File(h5file)

# %%
#print(gdataset)

# %%
print(hdataset)
# Out:
# <HDF5 file "test.h5" (mode r)>

# %%
hdataset.keys()
# Out:
# <KeysViewHDF5 ['DHI', 'DNI', 'GHI', 'INS', 'Projection_Information', 'X', 'Y', 'proj_dim', 'time']>

# %%
ghi=np.array(list(hdataset['GHI']))
ins=np.array(list(hdataset['INS']))
x=np.array(list(hdataset['X']))
y=np.array(list(hdataset['Y']))

# %%
#hdataset['GHI'].shape
#hdataset['INS'].shape
hdataset['X'].shape
#hdataset['Y'].shape
# Out:
# (1618,)

# %%
ghi=ghi.reshape(1616,1618)
ins=ins.reshape(1616,1618)

# %%
X, Y = np.meshgrid(x, y)
#Z =ghi
dummy = plt.contourf(X, Y, ghi, cmap='RdGy')
cbar = plt.colorbar(dummy)
plt.rc('xtick')#, labelsize=20) 
plt.rc('ytick')#, labelsize=20)
plt.rc('ghi')
plt.title("Radiation")
cbar.set_label('your label here')
#plt.colorbar();

# %%
#gdataset.seek(0)
#for g in gdataset:
#    print(g)
    #print(g.typeOfLevel, g.level, g.name, g.validDate, g.analDate, g.forecastTime)

# %%
#selected_grb = gdataset.select(name='V component of wind')[0]

# %%
#selected_grb
